# %%
# 기본
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import font_manager, rc
import platform
from tqdm import tqdm
import sklearn
from sklearn import linear_model
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from sklearn.model_selection import train_test_split

# time
import datetime

# crawling
import requests
import lxml.html
import sqlite3
from pandas.io import sql
from bs4 import BeautifulSoup

# 한글 폰트 설정
if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %%
air = pd.DataFrame()
year_list = ['2007', '2008', '2009', '2010', '2011', '2012', '2013']
term_list = ['01', '02', '03', '04']

for year in year_list: 
    for term in term_list: 
        tmp = pd.read_excel("D:\\SNUlab\\0. data\\thermal inversion\\대기\\{}년{}분기.xlsx".format(year, term))
        tmp = tmp.loc[tmp['측정소명'] == '백령도']
        air = pd.concat([air, tmp], axis = 0)

# 2014년은 csv임 - 따로
for term in term_list:    
    tmp = pd.read_csv("D:\\SNUlab\\0. data\\thermal inversion\\대기\\2014년{}분기.csv".format(term), encoding = 'euc-kr')
    tmp = tmp.loc[tmp['측정소명'] == '백령도']
    air = pd.concat([air, tmp], axis = 0)

# %%
tmp = pd.read_excel("D:\\SNUlab\\0. data\\thermal inversion\\대기\\2007년01분기.xlsx")

# %%
tmp
# Out:
#             지역    측정소명   측정소코드        측정일시    SO2   CO     O3    NO2  PM10  \
# 0           서울     청계천  111124  2007030304  0.005  0.4  0.003  0.034    26
# 1           서울     청계천  111124  2007030305  0.005  0.5  0.003  0.038    28
# 2           서울     청계천  111124  2007030306  0.005  0.3  0.003  0.038    31
# 3           서울     청계천  111124  2007030307  0.005  0.4  0.004  0.043    32
# 4           서울     청계천  111124  2007030309  0.006  0.6  0.004  0.047    51
# ...        ...     ...     ...         ...    ...  ...    ...    ...   ...
# 556531  인천 계양구  계양(폐쇄)  823661  2007022704  0.002  0.6  0.004  0.036    36
# 556532  인천 계양구  계양(폐쇄)  823661  2007022705  0.002  0.7  0.003  0.039    27
# 556533  인천 계양구  계양(폐쇄)  823661  2007031115  0.002  0.3  0.044  0.004    35
# 556534  인천 계양구  계양(폐쇄)  823661  2007031117  0.001  0.3  0.045  0.005    39
# 556535  인천 계양구  계양(폐쇄)  823661  2007031119  0.002  0.3  0.041  0.009    35
#
#                 주소
# 0        서울 중구 주교동
# 1        서울 중구 주교동
# 2        서울 중구 주교동
# 3        서울 중구 주교동
# 4        서울 중구 주교동
# ...            ...
# 556531  인천 계양구 장기동
# 556532  인천 계양구 장기동
# 556533  인천 계양구 장기동
# 556534  인천 계양구 장기동
# 556535  인천 계양구 장기동
#
# [556536 rows x 10 columns]

# %%
# 기본
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import font_manager, rc
import platform
from tqdm import tqdm
import sklearn
from sklearn import linear_model
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from sklearn.model_selection import train_test_split

# time
import datetime

# crawling
import requests
import lxml.html
import sqlite3
from pandas.io import sql
from bs4 import BeautifulSoup

# 한글 폰트 설정
if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %% [markdown]
# * 2021.11.23 CKD_final에 TIME 변수 추가한 df로 변경

# %%
# final = pd.read_csv('MME_final.csv', encoding = 'euc-kr', low_memory = False)
# final
# Out:
#         기수          NIHID  SEX  VISITALL  PHYSTB  PHYSIT  PHYACTL  PHYACTM  \
# 0      A01  NIH1604000095    2         6     1.0     5.0      7.0      6.0
# 1      A01  NIH1604000171    1         7     0.0     3.0      8.0      8.0
# 2      A01  NIH1604000338    1         7     2.0     5.0      3.0      0.0
# 3      A01  NIH1604000362    2         7     0.0     5.0      4.0      2.0
# 4      A01  NIH1604000424    1         4     8.0     5.0      8.0      8.0
# ...    ...            ...  ...       ...     ...     ...      ...      ...
# 70205  A07  NIH1604999643    2         7     NaN     NaN      NaN      NaN
# 70206  A07  NIH1604999732    1         6     NaN     NaN      NaN      NaN
# 70207  A07  NIH1604999772    1         6     NaN     NaN      NaN      NaN
# 70208  A07  NIH1604999929    2         4     NaN     NaN      NaN      NaN
# 70209  A07  NIH1604999956    1         1     NaN     NaN      NaN      NaN
#
# ...

# %%
final = pd.read_csv('data\\MME_.csv', encoding = 'euc-kr', low_memory = True)
final
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 70205  A07  201303.0  NIH1604999643  55.0    2   1.641    60.9   74.0
# 70206  A07  201407.0  NIH1604999732  75.0    1   1.632    50.8   81.3
# 70207  A07  201409.0  NIH1604999772  55.0    1   1.635    66.2   88.3
# 70208  A07  201403.0  NIH1604999929  53.0    2   1.530    63.2   85.3
# 70209  A07       NaN  NIH1604999956   NaN    1     NaN     NaN    NaN
#
#        GLU0_ORI  R_GTP_TR  ...  PHYACTM  PHYACTH  BODYFAT  MET_CAL  PA_NEW  \
# ...

# %%
final = final.loc[final['기수'] == 'A01']
final
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 10025  A01  200109.0  NIH1604999643  43.0    2   1.644    61.0   71.3
# 10026  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 10027  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 10028  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 10029  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#        GLU0_ORI  R_GTP_TR  ...  PHYACTM  PHYACTH  BODYFAT  MET_CAL  PA_NEW  \
# ...

# %%
ht = pd.read_csv('data//MME_drug_90//DRUGHT_drug90.csv', encoding = 'euc-kr')
ht
# Out:
#         기수          NIHID   EDATE_DAY  DRUGHT   DRUGHTYR1  DRUGHTCU DRUGHTYR2  \
# 0      A01  NIH1604001224  2002-09-15     2.0  1997-01-01       2.0       NaN
# 1      A01  NIH1604004091  2001-07-15     2.0  1996-01-01       2.0       NaN
# 2      A01  NIH1604004418  2001-10-15     2.0  2000-03-01       2.0       NaN
# 3      A01  NIH1604005066  2001-11-15     2.0  1998-01-01       2.0       NaN
# 4      A01  NIH1604006629  2002-01-15     2.0  2000-01-01       2.0       NaN
# ...    ...            ...         ...     ...         ...       ...       ...
# 11444  A07  NIH1604996566  2014-04-15     2.0  2009-01-01       2.0       NaN
# 11445  A07  NIH1604996909  2014-08-15     2.0  2008-01-01       2.0       NaN
# 11446  A07  NIH1604997100  2014-06-15     2.0  2002-01-01       2.0       NaN
# 11447  A07  NIH1604997534  2014-04-15     2.0  2013-01-01       2.0       NaN
# 11448  A07  NIH1604997938  2014-05-15     2.0  2009-03-01       2.0       NaN
#
# ...

# %%
# ckd = pd.read_csv('CKD_final_Baseline1st+OccuredTwiceOrMoreInARow.csv', encoding = 'euc-kr')
# ckd

# %%
# TIME 변수 들어가 있는 df로 수정
ckd = pd.read_csv('data\\CKD_final_TIMEadded_Baseline1st+OccuredTwiceOrMoreInARow.csv', encoding = 'euc-kr')
ckd
# Out:
#                NIHID  final_CKD  TIME
# 0      NIH1604000095          1   0.0
# 1      NIH1604000171          0  12.0
# 2      NIH1604000338          1  12.0
# 3      NIH1604000362          0   0.0
# 4      NIH1604000424          0   6.0
# ...              ...        ...   ...
# 10025  NIH1604999643          0  12.0
# 10026  NIH1604999732          0  12.0
# 10027  NIH1604999772          1  12.0
# 10028  NIH1604999929          0  12.0
# 10029  NIH1604999956          0   0.0
#
# [10030 rows x 3 columns]

# %%
# 1기만 뽑기
ht = ht.loc[ht['기수'] == 'A01']
ht
# Out:
#        기수          NIHID   EDATE_DAY  DRUGHT   DRUGHTYR1  DRUGHTCU DRUGHTYR2  \
# 0     A01  NIH1604001224  2002-09-15     2.0  1997-01-01       2.0       NaN
# 1     A01  NIH1604004091  2001-07-15     2.0  1996-01-01       2.0       NaN
# 2     A01  NIH1604004418  2001-10-15     2.0  2000-03-01       2.0       NaN
# 3     A01  NIH1604005066  2001-11-15     2.0  1998-01-01       2.0       NaN
# 4     A01  NIH1604006629  2002-01-15     2.0  2000-01-01       2.0       NaN
# ...   ...            ...         ...     ...         ...       ...       ...
# 1089  A01  NIH1604996728  2001-12-15     2.0  1991-01-01       2.0       NaN
# 1090  A01  NIH1604997100  2002-10-15     2.0  1999-12-01       2.0       NaN
# 1091  A01  NIH1604997594  2001-09-15     2.0  1998-01-01       2.0       NaN
# 1092  A01  NIH1604998140  2002-08-15     2.0  1999-01-01       2.0       NaN
# 1093  A01  NIH1604998251  2001-09-15     2.0  1999-01-01       2.0       NaN
#
# ...

# %%
ht = ht[['NIHID', 'drug_90']]

# %%
len(ht['NIHID'].unique())
# Out:
# 1094

# %%
ht_psm = pd.merge(final, ht, how = 'left', on = 'NIHID')

# %%
ht_psm
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 10025  A01  200109.0  NIH1604999643  43.0    2   1.644    61.0   71.3
# 10026  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 10027  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 10028  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 10029  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#        GLU0_ORI  R_GTP_TR  ...  PHYACTH  BODYFAT  MET_CAL  PA_NEW    SBP  \
# ...

# %%
ht_psm['drug_90'].isna().sum()
# Out:
# 8936

# %%
ht_psm = pd.merge(ht_psm, ckd, how = 'left', on = 'NIHID')
ht_psm
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 10025  A01  200109.0  NIH1604999643  43.0    2   1.644    61.0   71.3
# 10026  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 10027  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 10028  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 10029  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#        GLU0_ORI  R_GTP_TR  ...  MET_CAL  PA_NEW    SBP   DBP        eGFR  \
# ...

# %%
# 90일 미만으로 복용한 사람은 아예 복용하지 않은 사람과 동일하게 취급

ht_psm['drug_90'].fillna(0, inplace = True)

# %%
ht_psm['drug_90'].value_counts()
# Out:
# 0.0    8995
# 1.0    1035
# Name: drug_90, dtype: int64

# %%
ht_psm.rename(columns = {'drug_90' : 'ht_drug_90'}, inplace = True)
ht_psm
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 10025  A01  200109.0  NIH1604999643  43.0    2   1.644    61.0   71.3
# 10026  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 10027  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 10028  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 10029  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#        GLU0_ORI  R_GTP_TR  ...  MET_CAL  PA_NEW    SBP   DBP        eGFR  \
# ...

# %%
# ht_psm.drop(['MET_CAL', 'TOTALC', 'PHYACTL', 'PHYACTM', 'PHYACTH'], axis = 1, inplace = True)
# ht_psm

# %%
na_list = []
for col in ht_psm.columns: 
    if ht_psm[col].isna().sum() > 2000: 
        na_list.append(col)

# %%
na_list
# Out:
# ['TREATD5', 'TREATD14', 'KIDAG', 'KIDCU', 'BODYFAT']

# %%
ht_psm.drop(na_list, axis = 1, inplace = True)

# %%
ht_psm
# Out:
#         기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0      A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1      A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2      A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3      A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4      A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...    ...       ...            ...   ...  ...     ...     ...    ...
# 10025  A01  200109.0  NIH1604999643  43.0    2   1.644    61.0   71.3
# 10026  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 10027  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 10028  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 10029  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#        GLU0_ORI  R_GTP_TR  ...  MET_CAL  PA_NEW    SBP   DBP        eGFR  \
# ...

# %%
for col in ht_psm.columns: 
    print(col, ht_psm[col].isna().sum())
# Out:
# 기수 0
# EDATE 0
# NIHID 0
# AGE 0
# SEX 0
# HEIGHT 0
# WEIGHT 5
# WAIST 8
# GLU0_ORI 299
# R_GTP_TR 2
# AST_ORI 2
# ALT_ORI 5
# TCHL_ORI 2
# HDL_ORI 2
# TRIGLY_ORI 3
# HB_ORI 2
# SMOKE 134
# DRUGINS 585
# DRUGHT 585
# DRUGICD 585
# DRUGLP 585
# FMHTN 0
# FMHEA 0
# FMDM 0
# PRT16_U 37
# KID 4
# TOTALC 306
# PHYACTL 222
# PHYACTM 297
# PHYACTH 243
# MET_CAL 385
# PA_NEW 0
# SBP 19
# DBP 19
# eGFR 2
# BMI 5
# DRK_NEW 0
# ht_drug_90 0
# final_CKD 0
# TIME 2

# %%
ht_psm.dropna(inplace = True, axis = 0)
ht_psm.reset_index(drop = True, inplace = True)

# %%
ht_psm
# Out:
#        기수     EDATE          NIHID   AGE  SEX  HEIGHT  WEIGHT  WAIST  \
# 0     A01  200209.0  NIH1604000095  43.0    2   1.575    48.0   63.0
# 1     A01  200201.0  NIH1604000171  42.0    1   1.755    75.0   81.3
# 2     A01  200210.0  NIH1604000338  69.0    1   1.668    50.4   74.0
# 3     A01  200201.0  NIH1604000362  48.0    2   1.556    53.6   76.4
# 4     A01  200205.0  NIH1604000424  47.0    1   1.745    88.0   94.5
# ...   ...       ...            ...   ...  ...     ...     ...    ...
# 8366  A01  200111.0  NIH1604999640  44.0    2   1.606    57.0   69.0
# 8367  A01  200203.0  NIH1604999732  63.0    1   1.650    56.0   82.5
# 8368  A01  200301.0  NIH1604999772  44.0    1   1.640    68.5   83.0
# 8369  A01  200206.0  NIH1604999929  41.0    2   1.540    59.0   74.7
# 8370  A01  200301.0  NIH1604999956  43.0    1   1.760    79.5   88.0
#
#       GLU0_ORI  R_GTP_TR  ...  MET_CAL  PA_NEW    SBP   DBP        eGFR  \
# ...

# %%
ht_psm['ht_drug_90'].value_counts()
# Out:
# 0.0    7502
# 1.0     869
# Name: ht_drug_90, dtype: int64

# %%
ht_psm.to_csv('HT_psm.csv', encoding = 'euc-kr', index = False)

# %%
# 일단 7000명 정도로 na drop 해서 stepwise 돌려보기
# 부족하면 다시 10030명으로 할 수 있도록 칼럼을 줄이자

# (10.25) 신장 관련 변수 40개만 사용하기로 결정됨

# %% [markdown]
# -----------------------------

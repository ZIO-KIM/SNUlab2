# %%
# 기본
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import font_manager, rc
import platform
from tqdm import tqdm
import sklearn
from sklearn import linear_model
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from sklearn.model_selection import train_test_split

# crawling
import requests
import lxml.html
import sqlite3
from pandas.io import sql
from bs4 import BeautifulSoup

# 한글 폰트 설정
if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File __init__.pxd:943, in numpy.import_array()
#
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In [4], line 15
#      13 import scipy.stats as stats
#      14 from sklearn.preprocessing import StandardScaler
# ---> 15 import statsmodels.api as sm
#      16 import statsmodels.formula.api as smf
#      17 from statsmodels.stats.outliers_influence import variance_inflation_factor
#
# File c:\Users\user\anaconda3\lib\site-packages\statsmodels\api.py:105
#      94 from .genmod import api as genmod
#      95 from .genmod.api import (
#      96     GEE,
#      97     GLM,
#    (...)
#     103     families,
#     104 )
# --> 105 from .graphics import api as graphics
#     106 from .graphics.gofplots import ProbPlot, qqline, qqplot, qqplot_2samples
#     107 from .imputation.bayes_mi import MI, BayesGaussMI
#
# File c:\Users\user\anaconda3\lib\site-packages\statsmodels\graphics\api.py:9
#       7 from .gofplots import qqplot
#       8 from .plottools import rainbow
# ----> 9 from .regressionplots import (
#      10     abline_plot,
#      11     influence_plot,
#      12     plot_ccpr,
#      13     plot_ccpr_grid,
#      14     plot_fit,
#      15     plot_leverage_resid2,
#      16     plot_partregress,
#      17     plot_partregress_grid,
#      18     plot_regress_exog,
#      19 )
#      21 __all__ = [
#      22     "abline_plot",
#      23     "beanplot",
#    (...)
#      42     "violinplot",
#      43 ]
#
# File c:\Users\user\anaconda3\lib\site-packages\statsmodels\graphics\regressionplots.py:23
#      21 from statsmodels.genmod.generalized_linear_model import GLM
#      22 from statsmodels.graphics import utils
# ---> 23 from statsmodels.nonparametric.smoothers_lowess import lowess
#      24 from statsmodels.regression.linear_model import GLS, OLS, WLS
#      25 from statsmodels.sandbox.regression.predstd import wls_prediction_std
#
# File c:\Users\user\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:11
#       2 """Lowess - wrapper for cythonized extension
#       3
#       4 Author : Chris Jordan-Squire
#    (...)
#       7
#       8 """
#      10 import numpy as np
# ---> 11 from ._smoothers_lowess import lowess as _lowess
#      13 def lowess(endog, exog, frac=2.0/3.0, it=3, delta=0.0, xvals=None, is_sorted=False,
#      14            missing='drop', return_sorted=True):
#      15     '''LOWESS (Locally Weighted Scatterplot Smoothing)
#      16
#      17     A lowess function that outs smoothed estimates of endog
#    (...)
#     135
#     136     '''
#
# File statsmodels\nonparametric\_smoothers_lowess.pyx:22, in init statsmodels.nonparametric._smoothers_lowess()
#
# File __init__.pxd:945, in numpy.import_array()
#
# ImportError: numpy.core.multiarray failed to import

# %%
db = pd.read_csv('국건영_회귀분석용.csv', encoding = 'euc-kr')

# %%
db.describe()
# Out:
#                 year            sex            age          HE_ht  \
# count  113091.000000  113091.000000  113091.000000  106923.000000
# mean     2013.433430       1.544164      41.497113       1.564279
# std         3.958201       0.498048      22.781171       0.192820
# min      2007.000000       1.000000       1.000000       0.692000
# 25%      2010.000000       1.000000      22.000000       1.521000
# 50%      2013.000000       2.000000      43.000000       1.602000
# 75%      2017.000000       2.000000      60.000000       1.681000
# max      2020.000000       2.000000      80.000000       1.980000
#
#                HE_wt         HE_BMI        HE_obe       HE_Upro      HE_HbA1c  \
# count  107121.000000  105900.000000  82982.000000  87596.000000  65187.000000
# mean       57.260455      22.688933      2.480104      0.143774      5.784233
# std        17.828486       4.136232      0.791404      0.446323      0.877463
# min         7.000000       9.422775      1.000000      0.000000      3.100000
# 25%        49.800000      19.994864      2.000000      0.000000      5.300000
# 50%        58.600000      22.736350      2.000000      0.000000      5.600000
# 75%        68.200000      25.299746      3.000000      0.000000      5.900000
# max       164.800000      62.640542      6.000000      5.000000     17.300000
#
#              HE_glu  ...         DI3_pt        DI4_pt         DI1_pt  \
# count  89307.000000  ...  102481.000000  97471.000000  102481.000000
# mean      98.749930  ...       7.900538      7.835787       6.696149
# std       22.794224  ...       0.977345      1.076597       2.764006
# min       40.000000  ...       0.000000      0.000000       0.000000
# 25%       88.000000  ...       8.000000      8.000000       8.000000
# 50%       94.000000  ...       8.000000      8.000000       8.000000
# 75%      102.000000  ...       8.000000      8.000000       8.000000
# max      642.000000  ...       9.000000      8.000000       9.000000
#
#               DE1_pt         DI2_pt      HE_hepaB        BS6_2_2  \
# count  102481.000000  102481.000000  89407.000000  102468.000000
# mean        7.501771       7.202418      0.030266      73.841141
# std         1.837967       2.307928      0.171320      32.406375
# min         0.000000       0.000000      0.000000       0.000000
# 25%         8.000000       8.000000      0.000000      88.000000
# 50%         8.000000       8.000000      0.000000      88.000000
# 75%         8.000000       8.000000      0.000000      88.000000
# max         9.000000       9.000000      1.000000      99.000000
#
#                BS6_3         BS2_1           ABSI
# count  102468.000000  88300.000000  104991.000000
# mean      746.368125    528.232684       0.077303
# std       323.960835    422.251035       0.004875
# min         0.000000      1.000000       0.024133
# 25%       888.000000     22.000000       0.073969
# 50%       888.000000    888.000000       0.077130
# 75%       888.000000    888.000000       0.080458
# max       999.000000    999.000000       0.156476
#
# [8 rows x 39 columns]

# %%
for col in db.columns: 
    print(col, db[col].isna().sum())
# Out:
# year 0
# ID 0
# sex 0
# age 0
# psu 0
# HE_ht 6168
# HE_wt 5970
# HE_BMI 7191
# HE_obe 30109
# HE_Upro 25495
# HE_HbA1c 47904
# HE_glu 23784
# HE_chol 23736
# HE_ast 23680
# HE_alt 23688
# HE_wc 6826
# HE_HDL_st2 23748
# HE_LDL_drct 93407
# HE_crea 23690
# D_1_1 6981
# N_NA 13150
# BS3_1 10623
# BS3_2 10623
# BD1_11 9414
# BD2_1 9417
# BP1 9414
# DI3_dg 10610
# DI4_dg 15604
# DI1_dg 10610
# DE1_dg 6981
# DI2_dg 10610
# DI3_pt 10610
# DI4_pt 15620
# DI1_pt 10610
# DE1_pt 10610
# DI2_pt 10610
# HE_hepaB 23684
# BS6_2_2 10623
# BS6_3 10623
# BS2_1 24791
# ABSI 8100

# %%
# pycaret 사용한 모델 비교

# !pip install pycaret
# !pip install markupsafe==2.0.1
# Out:
# Collecting pycaret
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      -------------------------------------- 320.2/320.2 kB 9.7 MB/s eta 0:00:00
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp38-cp38-win_amd64.whl (152 kB)
#      -------------------------------------- 152.9/152.9 kB 4.5 MB/s eta 0:00:00
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ---------------------------------------- 81.7/81.7 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyod
#   Downloading pyod-1.0.7.tar.gz (147 kB)
#      -------------------------------------- 147.7/147.7 kB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plotly>=4.4.1
#   Downloading plotly-5.13.0-py2.py3-none-any.whl (15.2 MB)
#      --------------------------------------- 15.2/15.2 MB 16.0 MB/s eta 0:00:00
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3-cp38-cp38-win_amd64.whl (24.2 MB)
#      --------------------------------------- 24.2/24.2 MB 15.9 MB/s eta 0:00:00
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      -------------------------------------- 167.1/167.1 kB 9.8 MB/s eta 0:00:00
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 14.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting mlflow
#   Downloading mlflow-2.1.1-py3-none-any.whl (16.7 MB)
#      --------------------------------------- 16.7/16.7 MB 17.2 MB/s eta 0:00:00
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ------------------------------------- 324.4/324.4 kB 19.6 MB/s eta 0:00:00
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.9-cp38-cp38-win_amd64.whl (9.4 MB)
#      ---------------------------------------- 9.4/9.4 MB 17.1 MB/s eta 0:00:00
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 17.2 MB/s eta 0:00:00
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ------------------------------------- 282.6/282.6 kB 18.2 MB/s eta 0:00:00
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp38-cp38-win_amd64.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 18.2 MB/s eta 0:00:00
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp38-cp38-win_amd64.whl (6.8 MB)
#      ---------------------------------------- 6.8/6.8 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ------------------------------------- 636.8/636.8 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\lib\site-packages (from pycaret) (0.12.1)
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 16.1 MB/s eta 0:00:00
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 88.2/88.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk in c:\users\user\anaconda3\lib\site-packages (from pycaret) (3.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from pycaret) (3.6.2)
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.6/56.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: IPython in c:\users\user\anaconda3\lib\site-packages (from pycaret) (8.6.0)
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
#      ------------------------------------- 213.6/213.6 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
#      --------------------------------------- 31.4/31.4 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn==0.7.0->pycaret) (1.23.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn==0.23.2->pycaret) (2.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (1.16.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\user\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (65.5.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp38-cp38-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.17.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (2.11.2)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from IPython->pycaret) (0.1.6)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->pycaret) (6.15.2)
# Requirement already satisfied: wheel in c:\users\user\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 14.2 MB/s eta 0:00:00
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.4.2)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.20.3-cp38-cp38-win_amd64.whl (13.7 MB)
#      --------------------------------------- 13.7/13.7 MB 16.8 MB/s eta 0:00:00
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp38-cp38-win_amd64.whl (17.0 MB)
#      --------------------------------------- 17.0/17.0 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->pycaret) (2022.1)
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
#      ------------------------------------- 344.5/344.5 kB 10.8 MB/s eta 0:00:00
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.1-py3-none-any.whl (24 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp38-cp38-win_amd64.whl (831 kB)
#      ------------------------------------- 831.4/831.4 kB 17.5 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp38-cp38-win_amd64.whl (18 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-win_amd64.whl (198 kB)
#      -------------------------------------- 198.8/198.8 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<2.4.0->pycaret) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<2.4.0->pycaret) (2.28.1)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp38-cp38-win_amd64.whl (30 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.9-cp38-cp38-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 17.3 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.7/96.7 kB 5.8 MB/s eta 0:00:00
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      ------------------------------------- 274.2/274.2 kB 16.5 MB/s eta 0:00:00
#   Downloading yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
#      ------------------------------------- 271.4/271.4 kB 16.3 MB/s eta 0:00:00
# Collecting numpy>=1.13.3
#   Downloading numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
#      --------------------------------------- 13.3/13.3 MB 17.2 MB/s eta 0:00:00
# Collecting Jinja2<4,>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 8.2 MB/s eta 0:00:00
# Collecting shap<1,>=0.40
#   Downloading shap-0.41.0-cp38-cp38-win_amd64.whl (435 kB)
#      ------------------------------------- 435.6/435.6 kB 13.7 MB/s eta 0:00:00
# Collecting protobuf<5,>=3.12.0
#   Downloading protobuf-4.21.12-cp38-cp38-win_amd64.whl (527 kB)
#      ------------------------------------- 527.0/527.0 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.39)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ------------------------------------- 184.0/184.0 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.4)
# Requirement already satisfied: Flask<3 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Collecting pyarrow<11,>=4.0.0
#   Downloading pyarrow-10.0.1-cp38-cp38-win_amd64.whl (20.3 MB)
#      --------------------------------------- 20.3/20.3 MB 15.6 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ---------------------------------------- 147.5/147.5 kB ? eta 0:00:00
# Collecting sqlparse<1,>=0.4.0
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# Collecting waitress<3
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Collecting markdown<4,>=3.3
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.3/93.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ---------------------------------------- 82.3/82.3 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting alembic<2
#   Downloading alembic-1.9.3-py3-none-any.whl (210 kB)
#      ------------------------------------- 210.6/210.6 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3 in c:\users\user\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk->pycaret) (2022.7.9)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: numexpr in c:\users\user\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.8.4)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.0.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 15.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading pyLDAvis-3.2.2.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting funcy
#   Downloading funcy-1.18-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: statsmodels in c:\users\user\anaconda3\lib\site-packages (from pyod->pycaret) (0.13.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in c:\users\user\anaconda3\lib\site-packages (from alembic<2->mlflow->pycaret) (5.2.0)
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting oauthlib>=3.1.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 8.8 MB/s eta 0:00:00
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\user\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (305.1)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\user\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (0.58.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (1.26.13)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\user\anaconda3\lib\site-packages (from Flask<3->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\user\anaconda3\lib\site-packages (from Flask<3->mlflow->pycaret) (2.0.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->pycaret) (3.8.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (5.9.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.11.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->pycaret) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret) (2022.9.24)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\user\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.5.2)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\user\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.7/102.7 kB 5.8 MB/s eta 0:00:00
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.4-cp38-cp38-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 17.3 MB/s eta 0:00:00
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp38-cp38-win_amd64.whl (663 kB)
#      ------------------------------------- 663.3/663.3 kB 14.2 MB/s eta 0:00:00
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: networkx>=2.4 in c:\users\user\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\user\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (22.1.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 17.8 MB/s eta 0:00:00
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ------------------------------------- 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (1.3.10)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.4.8)
# Requirement already satisfied: nbconvert>=5 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (4.4.0)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.18.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.13)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: testpath in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.6.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: PyWavelets in c:\users\user\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.4.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Building wheels for collected packages: cufflinks, pyLDAvis, pyod, umap-learn, databricks-cli, pynndescent, htmlmin
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68718 sha256=bb234f6da2cd2cdd1783bba260c64bac935fc6978c594492ab2e7e3139ef2a19
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8b\0c\8c\6b052b6e9281a66c0618959319eb404b1ae6dba84c5505a4c6
#   Building wheel for pyLDAvis (setup.py): started
#   Building wheel for pyLDAvis (setup.py): finished with status 'done'
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.2.2-py2.py3-none-any.whl size=135600 sha256=5a6c203f9db4467a55808561cc517ee36977114497234aa2cc2315d96429b82a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1a\f5\9c\1e12ea674f33596577cd2e61f63dcca647221d7da8af75d738
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.7-py3-none-any.whl size=181085 sha256=a4e6a7e9b2da13337f992ae85a082652f5619d2333993f1fac062ee1c203185c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\d1\3b\3a\23d2c32d0fb16e7d5afb28e379c310a2c6789e853976a941a3
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82814 sha256=0bae68a548de4287cae99037c26753bd309c11f4a6f23a7286226ba2a6fe04e6
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\de\b2\e6\f3710dd75722ad40e856825ebdb090021a774e59f07d39bfc6
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142875 sha256=a6d8b0ec6ee7b301747bc2314d466bcd8fc4b9409a312ba6e6f76bf1e549b671
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\0a\0b\75\44edb38430dc44de74324d6e72d91d0d14d21df90349767335
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55496 sha256=6e6f380931152fbe8a2206ba86baba8718e4b3fc86b92f58e5d0991bf07d321b
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\c9\24\e3\9668804f30023bd253f22a9c37befce9d70a1f6507d7010c42
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=2f0cbd439eae6cc3d58655bf9d56a4e8e09c2f746d25baf825b6f4ec09dd7a1e
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\28\f3\26\826f91b0c848ff98f1725cd43014a6f3a2d961114157d790db
# Successfully built cufflinks pyLDAvis pyod umap-learn databricks-cli pynndescent htmlmin
# Installing collected packages: wasabi, plac, htmlmin, funcy, cymem, colorlover, waitress, typeguard, tenacity, tangled-up-in-unicode, tabulate, srsly, sqlparse, smmap, smart-open, slicer, querystring-parser, pyyaml, pyjwt, pydantic, protobuf, oauthlib, numpy, murmurhash, multimethod, Mako, llvmlite, Jinja2, Cython, catalogue, scipy, pyarrow, preshed, plotly, numba, markdown, gitdb, docker, databricks-cli, blis, alembic, visions, thinc, textblob, scikit-learn, pyLDAvis, imagehash, gitpython, gensim, yellowbrick, wordcloud, spacy, shap, scikit-plot, pyod, pynndescent, phik, mlxtend, lightgbm, kmodes, imbalanced-learn, Boruta, ydata-profiling, umap-learn, mlflow, pandas-profiling, cufflinks, pycaret
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\user\\AppData\\Local\\Temp\\pip-uninstall-2t_alrjg\\core\\_multiarray_tests.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: markupsafe==2.0.1 in c:\users\user\anaconda3\lib\site-packages (2.0.1)

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 from pycaret.regression import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

import os
from tqdm import tqdm
import json
import shutil
import pydicom
# image data
from PIL import Image
import glob
# import cv2

# %%
ll = [1,1, 1, 2,3, -1,5,6,12]
l2 = [1, 2,3, ]

L = []
print(L)
L.append(ll)
L.append(l2)
print(L)

# %%
fig, ax = plt.subplots()
ax.boxplot(L)
#plt.boxplot(ll,  sym='r+')
#plt.xticks([1,2], ["a","b"])
plt.show()

# %%
l = [1,2,3]
print(min(l))

# %% [markdown]
# ## LEFT Kidney 'X' - PRE

# %%
#LEFT Kidney 'X' - PRE

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


x_min_leftKidney_pre = []
x_max_leftKidney_pre = []

#LEFT_PRE
for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_train + folder +'/' + folder + '_PRE.json'
    else:
        path = file_path_test+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_test + folder +'/' + folder + '_PRE.json'
        
    #with open(ppl_ARTlabel_path) as f:
    with open(ppl_PRElabel_path) as f: 
        PRE_json = json.load(f)
    length = len(PRE_json['roi_list']['left kidney'])
    
    x_list = []
    for i in range(length): 
        
        x_list.append(PRE_json['roi_list']['left kidney'][i]['x'])
        x_list = list(set(x_list))
    if x_list: 
        #print(folder)
        #print(x_list)
        x_min_leftKidney_pre.append(min(x_list))
        x_max_leftKidney_pre.append(max(x_list))
print("---------------------------")
print(len(x_min_leftKidney_pre))
print(len(x_max_leftKidney_pre))   
print(x_min_leftKidney_pre)
print(x_max_leftKidney_pre)

fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([x_min_leftKidney_pre, x_max_leftKidney_pre])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("left kidney x_list (PRE)")
plt.show() 

num_x_min = pd.Series(x_min_leftKidney_pre)
Q1 = num_x_min.quantile(.25)
Q2 = num_x_min.quantile(.5)
Q3 = num_x_min.quantile(.75)
print("<< x_min_leftKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_x_max = pd.Series(x_max_leftKidney_pre)
Q1 = num_x_max.quantile(.25)
Q2 = num_x_max.quantile(.5)
Q3 = num_x_max.quantile(.75)
print("<< x_max_leftKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## LEFT Kidney 'Y' - PRE

# %%
#LEFT Kidney 'Y' - PRE

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


y_min_leftKidney_pre = []
y_max_leftKidney_pre = []

#LEFT_PRE
for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_train + folder +'/' + folder + '_PRE.json'
    else:
        path = file_path_test+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_test + folder +'/' + folder + '_PRE.json'
        
    #with open(ppl_ARTlabel_path) as f:
    with open(ppl_PRElabel_path) as f: 
        PRE_json = json.load(f)
    length = len(PRE_json['roi_list']['left kidney'])
    
    y_list = []
    for i in range(length): 
        
        y_list.append(PRE_json['roi_list']['left kidney'][i]['y'])
        y_list = list(set(y_list))
    if y_list: 
        #print(folder)
        #print(y_list)
        y_min_leftKidney_pre.append(min(y_list))
        y_max_leftKidney_pre.append(max(y_list))

print(len(y_min_leftKidney_pre))
print(len(y_max_leftKidney_pre))   
print(y_min_leftKidney_pre)
print(y_max_leftKidney_pre)
    
fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([y_min_leftKidney_pre, y_max_leftKidney_pre])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("left kidney y_list (PRE)")
plt.show() 

num_y_min = pd.Series(y_min_leftKidney_pre)
Q1 = num_y_min.quantile(.25)
Q2 = num_y_min.quantile(.5)
Q3 = num_y_min.quantile(.75)
print("<< y_min_leftKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_y_max = pd.Series(y_max_leftKidney_pre)
Q1 = num_y_max.quantile(.25)
Q2 = num_y_max.quantile(.5)
Q3 = num_y_max.quantile(.75)
print("<< y_max_leftKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## RIGHT Kidney 'X' - PRE

# %%
#RIGHT Kidney 'X' - PRE

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


x_min_rightKidney_pre = []
x_max_rightKidney_pre = []

#RIGHT_PRE
for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_train + folder +'/' + folder + '_PRE.json'
    else:
        path = file_path_test+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_test + folder +'/' + folder + '_PRE.json'
        
    #with open(ppl_ARTlabel_path) as f:
    with open(ppl_PRElabel_path) as f: 
        PRE_json = json.load(f)
    length = len(PRE_json['roi_list']['right kidney'])
    
    x_list = []
    for i in range(length): 
        
        x_list.append(PRE_json['roi_list']['right kidney'][i]['x'])
        x_list = list(set(x_list))
    if x_list: 
        #print(folder)
        #print(x_list)
        x_min_rightKidney_pre.append(min(x_list))
        x_max_rightKidney_pre.append(max(x_list))

print(len(x_min_rightKidney_pre))
print(len(x_max_rightKidney_pre))   
print(x_min_rightKidney_pre)
print(x_max_rightKidney_pre)
    
fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([x_min_rightKidney_pre, x_max_rightKidney_pre])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("right kidney x_list (PRE)")
plt.show() 


num_x_min = pd.Series(x_min_rightKidney_pre)
Q1 = num_x_min.quantile(.25)
Q2 = num_x_min.quantile(.5)
Q3 = num_x_min.quantile(.75)
print("<< x_min_rightKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_x_max = pd.Series(x_max_rightKidney_pre)
Q1 = num_x_max.quantile(.25)
Q2 = num_x_max.quantile(.5)
Q3 = num_x_max.quantile(.75)
print("<< x_max_rightKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## RIGHT Kidney 'Y' - PRE

# %%
#RIGHT Kidney 'Y' - PRE

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


y_min_rightKidney_pre = []
y_max_rightKidney_pre = []


for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_train + folder +'/' + folder + '_PRE.json'
    else:
        path = file_path_test+folder+'/'+folder+'_PRE/'
        file_names = os.listdir(path)
        ppl_PRElabel_path = LABEL_path_test + folder +'/' + folder + '_PRE.json'
        
    #with open(ppl_ARTlabel_path) as f:
    with open(ppl_PRElabel_path) as f: 
        PRE_json = json.load(f)
    length = len(PRE_json['roi_list']['right kidney'])
    
    y_list = []
    for i in range(length): 
        
        y_list.append(PRE_json['roi_list']['right kidney'][i]['y'])
        y_list = list(set(y_list))
    if y_list: 
        print(folder)
        print(y_list)
        y_min_rightKidney_pre.append(min(y_list))
        y_max_rightKidney_pre.append(max(y_list))

print(len(y_min_rightKidney_pre))
print(len(y_max_rightKidney_pre))   
print(y_min_rightKidney_pre)
print(y_max_rightKidney_pre)
    
fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([y_min_rightKidney_pre, y_max_rightKidney_pre])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("right kidney y_list (PRE)")
plt.show() 


num_y_min = pd.Series(y_min_rightKidney_pre)
Q1 = num_y_min.quantile(.25)
Q2 = num_y_min.quantile(.5)
Q3 = num_y_min.quantile(.75)
print("<< y_min_rightKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_y_max = pd.Series(y_max_rightKidney_pre)
Q1 = num_y_max.quantile(.25)
Q2 = num_y_max.quantile(.5)
Q3 = num_y_max.quantile(.75)
print("<< y_max_rightKidney_pre >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %%
####################### ART ############################

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

import os
from tqdm import tqdm
import json
import shutil
import pydicom
# image data
from PIL import Image
import glob
# import cv2

# %% [markdown]
# ## LEFT Kidney 'X' - ART

# %%
#LEFT Kidney 'X' - ART

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


x_min_leftKidney_art = []
x_max_leftKidney_art = []

#LEFT_PRE
for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'
    else:
        path = file_path_test+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        pplARTlabel_path = LABEL_path_test + folder +'/' + folder + '_ART.json'
        
    with open(ppl_ARTlabel_path) as f:
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['left kidney'])
    
    x_list = []
    for i in range(length): 
        
        x_list.append(ART_json['roi_list']['left kidney'][i]['x'])
        x_list = list(set(x_list))
    if x_list: 
        #print(folder)
        #print(x_list)
        x_min_leftKidney_art.append(min(x_list))
        x_max_leftKidney_art.append(max(x_list))

print(len(x_min_leftKidney_art))
print(len(x_max_leftKidney_art))   
print(x_min_leftKidney_art)
print(x_max_leftKidney_art)

fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([x_min_leftKidney_art, x_max_leftKidney_art])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("left kidney x_list (ART)")
plt.show() 

num_x_min = pd.Series(x_min_leftKidney_art)
Q1 = num_x_min.quantile(.25)
Q2 = num_x_min.quantile(.5)
Q3 = num_x_min.quantile(.75)
print("<< x_min_leftKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_x_max = pd.Series(x_max_leftKidney_art)
Q1 = num_x_max.quantile(.25)
Q2 = num_x_max.quantile(.5)
Q3 = num_x_max.quantile(.75)
print("<< x_max_leftKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## LEFT Kidney 'Y' - ART

# %%
#LEFT Kidney 'X' - ART

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


y_min_leftKidney_art = []
y_max_leftKidney_art = []

#LEFT_PRE
for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'
    else:
        path = file_path_test+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        pplARTlabel_path = LABEL_path_test + folder +'/' + folder + '_ART.json'
        
    with open(ppl_ARTlabel_path) as f:
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['left kidney'])
    
    y_list = []
    for i in range(length): 
        
        y_list.append(ART_json['roi_list']['left kidney'][i]['y'])
        y_list = list(set(y_list))
    if y_list: 
        #print(folder)
        #print(y_list)
        y_min_leftKidney_art.append(min(y_list))
        y_max_leftKidney_art.append(max(y_list))

print(len(y_min_leftKidney_art))
print(len(y_max_leftKidney_art))   
print(y_min_leftKidney_art)
print(y_max_leftKidney_art)

fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([y_min_leftKidney_art, y_max_leftKidney_art])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("left kidney y_list (ART)")
plt.show() 



num_y_min = pd.Series(y_min_leftKidney_art)
Q1 = num_y_min.quantile(.25)
Q2 = num_y_min.quantile(.5)
Q3 = num_y_min.quantile(.75)
print("<< y_min_leftKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_y_max = pd.Series(y_max_leftKidney_art)
Q1 = num_y_max.quantile(.25)
Q2 = num_y_max.quantile(.5)
Q3 = num_y_max.quantile(.75)
print("<< y_max_leftKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## RIGHT Kidney 'X' - ART

# %%
#RIGHT Kidney 'X' - ART

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


x_min_rightKidney_art = []
x_max_rightKidney_art = []


for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'
    else:
        path = file_path_test+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        pplARTlabel_path = LABEL_path_test + folder +'/' + folder + '_ART.json'
        
    with open(ppl_ARTlabel_path) as f:
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['right kidney'])
    
    x_list = []
    for i in range(length): 
        
        x_list.append(ART_json['roi_list']['right kidney'][i]['x'])
        x_list = list(set(x_list))
    if x_list: 
        #print(folder)
        #print(x_list)
        x_min_rightKidney_art.append(min(x_list))
        x_max_rightKidney_art.append(max(x_list))

print(len(x_min_rightKidney_art))
print(len(x_max_rightKidney_art))   
print(x_min_rightKidney_art)
print(x_max_rightKidney_art)

fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([x_min_rightKidney_art, x_max_rightKidney_art])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("right kidney x_list (ART)")
plt.show() 


num_x_min = pd.Series(x_min_rightKidney_art)
Q1 = num_x_min.quantile(.25)
Q2 = num_x_min.quantile(.5)
Q3 = num_x_min.quantile(.75)
print("<< x_min_rightKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_x_max = pd.Series(x_max_rightKidney_art)
Q1 = num_x_max.quantile(.25)
Q2 = num_x_max.quantile(.5)
Q3 = num_x_max.quantile(.75)
print("<< x_max_rightKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

# %% [markdown]
# ## RIGHT Kidney 'X' - ART

# %%
#RIGHT Kidney 'X' - ART

pt_num = []
for i in range(1,361):
    pt_num.append(i)
    
except_num = [108, 148, 184, 309, 323]

pt_num = list(set(pt_num)-set(except_num))
#print(len(pt_num))
    


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'
LABEL_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/라벨링데이터/'
file_path_test = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/2.Validation/원천데이터/'


y_min_rightKidney_art = []
y_max_rightKidney_art = []


for f in pt_num: 
    if f < 10:
        folder = '02_01_000{}'.format(f)
    elif f < 100:
        folder = '02_01_00{}'.format(f)
    else:
        folder = '02_01_0{}'.format(f)
    
    if f < 321:
        path = file_path_train+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'
    else:
        path = file_path_test+folder+'/'+folder+'_ART/'
        file_names = os.listdir(path)
        pplARTlabel_path = LABEL_path_test + folder +'/' + folder + '_ART.json'
        
    with open(ppl_ARTlabel_path) as f:
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['right kidney'])
    
    y_list = []
    for i in range(length): 
        
        y_list.append(ART_json['roi_list']['right kidney'][i]['y'])
        y_list = list(set(y_list))
    if y_list: 
        #print(folder)
        #print(y_list)
        y_min_rightKidney_art.append(min(y_list))
        y_max_rightKidney_art.append(max(y_list))

print(len(y_min_rightKidney_art))
print(len(y_max_rightKidney_art))   
print(y_min_rightKidney_art)
print(y_max_rightKidney_art)

fig, ax = plt.subplots()
fig.subplots_adjust(wspace=1)
ax.boxplot([y_min_rightKidney_art, y_max_rightKidney_art])
#plt.boxplot(ll,  sym='r+')
plt.xticks([1,2], ["min","max"])
plt.title("right kidney y_list (ART)")
plt.show() 


num_y_min = pd.Series(y_min_rightKidney_art)
Q1 = num_y_min.quantile(.25)
Q2 = num_y_min.quantile(.5)
Q3 = num_y_min.quantile(.75)
print("<< y_min_rightKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

num_y_max = pd.Series(y_max_rightKidney_art)
Q1 = num_y_max.quantile(.25)
Q2 = num_y_max.quantile(.5)
Q3 = num_y_max.quantile(.75)
print("<< y_max_rightKidney_art >>")
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Q3: ",Q3)

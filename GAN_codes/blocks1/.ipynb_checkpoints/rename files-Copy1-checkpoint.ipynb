# %%
import os
import glob

path = '/home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART'
#path = '/home/ncp/workspace/blocks1/RCC/PRE'
file_names = glob.glob(path+'/*')
print(len(file_names))
for f in file_names: 
    print(f)
    #os.rename(f, os.path.join(path, f[59:75]+'png')) #train
    #os.rename(f, os.path.join(path, f[58:74]+'png')) #test
    print(f[59:75]+'png')
   # 33590914_RCC200015.jpg
# Out:
# 32769
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0010_0073.png
# 02_01_0010_0073.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0197_0015.png
# 02_01_0197_0015.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0028_0016.png
# 02_01_0028_0016.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0028_0011.png
# 02_01_0028_0011.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0205_0005.png
# 02_01_0205_0005.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0110_0120.png
# 02_01_0110_0120.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0264_0046.png
# 02_01_0264_0046.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0236_0019.png
# 02_01_0236_0019.png
# /home/ncp/workspace/blocks1/kidneyData_windowing/TRAIN/ART/02_01_0161_0029.png
# 02_01_0161_0029.png
# ...

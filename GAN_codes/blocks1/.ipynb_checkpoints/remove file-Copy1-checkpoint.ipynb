# %%
#abdomen config
p1 = '/home/ncp/workspace/blocks1/kidneyData_windowing/Train_data/ART/'
p2 = '/home/ncp/workspace/blocks1/kidneyData_windowing/Train_data/PRE/'
p3 = '/home/ncp/workspace/blocks1/kidneyData_windowing/Test_data/ART/'
p4 = '/home/ncp/workspace/blocks1/kidneyData_windowing/Test_data/PRE/'

# %%
#abdomen config
p1 = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass/Train_data/ART/'
p2 = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass/Train_data/PRE/'
p3 = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass/Test_data/ART/'
p4 = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass/Test_data/PRE/'

# %%
import os
f1 = os.listdir(p1)
f2 = os.listdir(p2)
f3 = os.listdir(p3)
f4 = os.listdir(p4)

# %%
#abdomen config_total
print(len(f1))
print(len(f2))
print(len(f3))
print(len(f4))
#print(len(F))
# Out:
# 2398
# 0
# 323
# 331

# %%
import os
file_names = os.listdir(p2)
fn = []

   
img = [file for file in file_names if file.startswith('02_01_0148')]
print(img) 
for i in img:    
   # os.remove(p2+i)
# Out:
# []

# %%
cd '/home/ncp/workspace/blocks1/kidneyData_windowing(h)/Test_data/PRE/'
# Out:
# /home/ncp/workspace/blocks1/kidneyData_windowing(h)/Test_data/PRE

# %%
ls
# Out:
# 02_01_0340_0001.dcm.png  02_01_0346_0175.dcm.png  02_01_0354_0029.dcm.png
# 02_01_0340_0002.dcm.png  02_01_0346_0176.dcm.png  02_01_0354_0030.dcm.png
# 02_01_0340_0003.dcm.png  02_01_0346_0177.dcm.png  02_01_0354_0031.dcm.png
# 02_01_0340_0004.dcm.png  02_01_0346_0178.dcm.png  02_01_0354_0032.dcm.png
# 02_01_0340_0005.dcm.png  02_01_0346_0179.dcm.png  02_01_0354_0033.dcm.png
# 02_01_0340_0006.dcm.png  02_01_0346_0180.dcm.png  02_01_0354_0034.dcm.png
# 02_01_0340_0007.dcm.png  02_01_0346_0181.dcm.png  02_01_0354_0035.dcm.png
# 02_01_0340_0008.dcm.png  02_01_0346_0182.dcm.png  02_01_0354_0036.dcm.png
# 02_01_0340_0009.dcm.png  02_01_0346_0183.dcm.png  02_01_0354_0037.dcm.png
# 02_01_0340_0010.dcm.png  02_01_0346_0184.dcm.png  02_01_0354_0038.dcm.png
# 02_01_0340_0011.dcm.png  02_01_0346_0185.dcm.png  02_01_0354_0039.dcm.png
# 02_01_0340_0012.dcm.png  02_01_0346_0186.dcm.png  02_01_0354_0040.dcm.png
# 02_01_0340_0013.dcm.png  02_01_0346_0187.dcm.png  02_01_0354_0041.dcm.png
# ...

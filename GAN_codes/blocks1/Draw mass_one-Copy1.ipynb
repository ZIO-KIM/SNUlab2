# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

import os
from tqdm import tqdm
import json
import shutil
import pydicom

from PIL import Image
from PIL import ImageDraw
import glob

# %% [markdown]
# ## image - One by One

# %%
#Original
image_path = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass_total/ART/02_01_0001_0049.png'
img=Image.open(image_path)

img

# %%
#Draw Circle

pt_num = [1]


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'


x_leftMass_art = []
y_leftMass_art = []

#LEFT_ART
for f in pt_num: 
    f = format(f,'04d')
    folder = '02_01_'+f
        
    path_ = file_path_train+folder+'/'+folder+'_ART/'
    print(path_)
    file_names = os.listdir(path_)
    num = len(file_names) #the number of eacg patient's total CT images
    

    ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'

    with open(ppl_ARTlabel_path) as f: 
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['left mass']) #keyword / ex. left mass, right mass2, left kidney
    z_list = []
    for i in range(length): 
        z_list.append(ART_json['roi_list']['left mass'][i]['z']) #extract 'z' coordinate of mass images
    z_list = list(set(z_list))
    x_list = []
    y_list = []
    
    for j in z_list:
        for i in range(length): 
            if ART_json['roi_list']['left mass'][i]['z'] == j:
                x_list.append(ART_json['roi_list']['left mass'][i]['x'])
                y_list.append(ART_json['roi_list']['left mass'][i]['y'])
        x_leftMass_art.append(x_list) # 3, 4, 5 png [[],[],[]]
        y_leftMass_art.append(y_list)
        x_list=[]
        y_list=[]


    file_names = glob.glob(path_+'/*')

    if len(z_list) > 0:
        for j in z_list:
            for f in file_names: 
                header = pydicom.dcmread(f, stop_before_pixels = True)
                h_num = header.InstanceNumber 
                if h_num == num-j:#find the number of png
                    print(f[111:115]) #

                   
print("---------------------------")

print(len(x_leftMass_art[1])) #index of png numeber
print(len(y_leftMass_art[1]))
n = len(x_leftMass_art[1])
image_path = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass_total/ART/02_01_0001_0049.png'
img=Image.open(image_path).convert('RGB')
draw=ImageDraw.Draw(img,'RGBA')
r=1 #radius

for i in range(n):
    x = x_leftMass_art[1][i]
    y = y_leftMass_art[1][i]
    draw.ellipse((x-r, y-r, x+r, y+r), fill=(255,0,0,20)) #the fourth parameter of fill is related to the opacity
img

# %%
#Draw Rectangle

pt_num = [210]


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'


x_leftMass_art = []
y_leftMass_art = []

#LEFT_ART
for f in pt_num: 
    f = format(f,'04d')
    folder = '02_01_'+f
        
    path_ = file_path_train+folder+'/'+folder+'_ART/'
    print(path_)
    file_names = os.listdir(path_)
    num = len(file_names) #the number of eacg patient's total CT images
    

    ppl_ARTlabel_path = LABEL_path_train + folder +'/' + folder + '_ART.json'

    with open(ppl_ARTlabel_path) as f: 
        ART_json = json.load(f)
    length = len(ART_json['roi_list']['left mass']) #keyword / ex. left mass, right mass2, left kidney
    z_list = []
    for i in range(length): 
        z_list.append(ART_json['roi_list']['left mass'][i]['z']) #extract 'z' coordinate of mass images
    z_list = list(set(z_list))
    x_list = []
    y_list = []
    
    for j in z_list:
        for i in range(length): 
            if ART_json['roi_list']['left mass'][i]['z'] == j:
                x_list.append(ART_json['roi_list']['left mass'][i]['x'])
                y_list.append(ART_json['roi_list']['left mass'][i]['y'])
        x_leftMass_art.append(x_list) # 3, 4, 5 png [[],[],[]]
        y_leftMass_art.append(y_list)
        x_list=[]
        y_list=[]


    file_names = glob.glob(path_+'/*')

    if len(z_list) > 0:
        for j in z_list:
            for f in file_names: 
                header = pydicom.dcmread(f, stop_before_pixels = True)
                h_num = header.InstanceNumber 
                if h_num == num-j:#find the number of png
                    print(f[111:115]) #

                   
print("---------------------------")

print(len(x_leftMass_art[1])) #index of png numeber
print(len(y_leftMass_art[1]))
n = len(x_leftMass_art[1])
image_path = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass_total/ART/02_01_0210_0028.png'
img=Image.open(image_path).convert('RGB')
draw=ImageDraw.Draw(img,'RGBA')
r=1 #radius


x_max = max(x_leftMass_art[1])
x_min = min(x_leftMass_art[1])
y_max = max(y_leftMass_art[1])
y_min = min(y_leftMass_art[1])
draw.rectangle((x_min, y_min, x_max, y_max), outline=(255,0,0)) #the fourth parameter of fill is related to the opacity
img

# %%
#Draw Rectangle

pt_num = [210]


LABEL_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/라벨링데이터/'
file_path_train = '/home/ncp/workspace/202002n035/035.신장암 진단을 위한 의료 영상 데이터/01.데이터/신장암2/1.Training/원천데이터/'


x_leftMass_pre = []
y_leftMass_pre = []

#LEFT_pre
for f in pt_num: 
    f = format(f,'04d')
    folder = '02_01_'+f
        
    path_ = file_path_train+folder+'/'+folder+'_PRE/'
    print(path_)
    file_names = os.listdir(path_)
    num = len(file_names) #the number of eacg patient's total CT images
    

    ppl_PRElabel_path = LABEL_path_train + folder +'/' + folder + '_PRE.json'

    with open(ppl_PRElabel_path) as f: 
        PRE_json = json.load(f)
    length = len(PRE_json['roi_list']['left mass']) #keyword / ex. left mass, right mass2, left kidney
    z_list = []
    for i in range(length): 
        z_list.append(PRE_json['roi_list']['left mass'][i]['z']) #extract 'z' coordinate of mass images
    z_list = list(set(z_list))
    x_list = []
    y_list = []
    
    for j in z_list:
        for i in range(length): 
            if PRE_json['roi_list']['left mass'][i]['z'] == j:
                x_list.append(PRE_json['roi_list']['left mass'][i]['x'])
                y_list.append(PRE_json['roi_list']['left mass'][i]['y'])
        x_leftMass_pre.append(x_list) # 3, 4, 5 png [[],[],[]]
        y_leftMass_pre.append(y_list)
        x_list=[]
        y_list=[]


    file_names = glob.glob(path_+'/*')

    if len(z_list) > 0:
        for j in z_list:
            for f in file_names: 
                header = pydicom.dcmread(f, stop_before_pixels = True)
                h_num = header.InstanceNumber 
                if h_num == num-j:#find the number of png
                    print(f[111:115]) #

                   
print("---------------------------")

print(len(x_leftMass_pre[1])) #index of png numeber
print(len(y_leftMass_pre[1]))
n = len(x_leftMass_pre[1])
image_path = '/home/ncp/workspace/blocks1/kidneyData_windowing_mass_total/PRE/02_01_0210_0029.png'
img=Image.open(image_path).convert('RGB')
draw=ImageDraw.Draw(img,'RGBA')
r=1 #radius


x_max = max(x_leftMass_pre[1])
x_min = min(x_leftMass_pre[1])
y_max = max(y_leftMass_pre[1])
y_min = min(y_leftMass_pre[1])
draw.rectangle((x_min, y_min, x_max, y_max), outline=(255,0,0)) #the fourth parameter of fill is related to the opacity
img
